# %% [markdown]
# Adriel Vincent Zagala Video Games Data Set
#
# ***
#
# Part 1 EXTRACT

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.lines as mlines

path = r'C:\Users\bwelp\Desktop\Cognixia\Cognixia Projects\Project3\Video_Games.csv'
df = pd.read_csv(path)

# %% [markdown]
# ***
# Part 2 TRANSFORM

# %%
df
"""
Records Before any  Changes
"""
# Out:
# '\nRecords Before any  Changes\n'

# %%
df = df.dropna()
#Removed any records with any NaN Values in any columns

# %%
global_sales = df[['Name','Platform','Year_of_Release','Genre','Publisher','Global_Sales','Critic_Score','User_Score','Developer','Rating']]
global_sales['Year_of_Release'] = global_sales['Year_of_Release'].astype('datetime64[D]')
global_sales['User_Score'] = global_sales['User_Score'].astype(float)
global_sales
# Out:
# C:\Users\bwelp\AppData\Local\Temp\ipykernel_12496\258682511.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   global_sales['Year_of_Release'] = global_sales['Year_of_Release'].astype('datetime64[D]')
# C:\Users\bwelp\AppData\Local\Temp\ipykernel_12496\258682511.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   global_sales['User_Score'] = global_sales['User_Score'].astype(float)
#                                     Name Platform Year_of_Release     Genre  \
# ...

# %% [markdown]
# ***
# Part 3 ANALYZE

# %%
lowest_crit_scores = global_sales.query('Critic_Score == Critic_Score.min()')
lowest_crit_score = global_sales['Critic_Score'].min()

print("Lowest Critic Score:", lowest_crit_score)#shows the highest Critic Score
lowest_crit_scores #shows the list of records with the highest score
# Out:
# Lowest Critic Score: 13.0
#                Name Platform Year_of_Release   Genre    Publisher  \
# 13690  Ride to Hell      PS3      1975-07-07  Racing  Deep Silver
#
#        Global_Sales  Critic_Score  User_Score               Developer Rating
# 13690          0.04          13.0         1.0  Eutechnyx, Deep Silver      M

# %%
highest_crit_scores = global_sales.query('Critic_Score == Critic_Score.max()')
highest_crit_score = global_sales['Critic_Score'].max()

print("Highest Critic Score:", highest_crit_score)#shows the highest Critic Score
highest_crit_scores #shows the list of records with the highest score
# Out:
# Highest Critic Score: 98.0
#                           Name Platform Year_of_Release     Genre  \
# 51         Grand Theft Auto IV     X360      1975-07-02    Action
# 57         Grand Theft Auto IV      PS3      1975-07-02    Action
# 227   Tony Hawk's Pro Skater 2       PS      1975-06-24    Sports
# 5350               SoulCalibur       DC      1975-06-23  Fighting
#
#                  Publisher  Global_Sales  Critic_Score  User_Score  \
# 51    Take-Two Interactive         11.01          98.0         7.9
# 57    Take-Two Interactive         10.50          98.0         7.5
# 227             Activision          4.68          98.0         7.7
# 5350    Namco Bandai Games          0.34          98.0         8.8
#
#                     Developer Rating
# 51             Rockstar North      M
# 57             Rockstar North      M
# 227   Neversoft Entertainment      T
# 5350                    Namco      T

# %%
avg_crit_score = global_sales['Critic_Score'].mean().round()
print("Average Critic Score:",avg_crit_score)
# Out:
# Average Critic Score: 70.0

# %%
min_user_scores = global_sales.query('User_Score == User_Score.min()')
min_user_score = global_sales['User_Score'].min()

print("Lowest User Score:", min_user_score) #shows the Lowest User Score
min_user_scores #shows the list of records with the Lowest score
# Out:
# Lowest User Score: 0.5
#                                     Name Platform Year_of_Release      Genre  \
# 9148    Power Gig: Rise of the SixString      PS3      1975-07-04       Misc
# 10263  Charlie and the Chocolate Factory       XB      1975-06-29  Adventure
#
#          Publisher  Global_Sales  Critic_Score  User_Score  \
# 9148       Unknown          0.14          36.0         0.5
# 10263  Global Star          0.11          39.0         0.5
#
#                                            Developer Rating
# 9148                                 Seven45 Studios      T
# 10263  High Voltage Software, Backbone Entertainment      E

# %%
highest_user_scores = global_sales.query('User_Score == User_Score.max()')
highest_user_score = global_sales['User_Score'].max()

print("Highest User Score:", highest_user_score) #shows the Highest User Score
highest_user_scores #shows the list of records with the Highest score
# Out:
# Highest User Score: 9.6
#                                        Name Platform Year_of_Release  \
# 3417  Harvest Moon: Friends of Mineral Town      GBA      1975-06-27
# 8976        Boktai: The Sun is in Your Hand      GBA      1975-06-27
#
#              Genre                     Publisher  Global_Sales  Critic_Score  \
# 3417    Simulation                       Ubisoft          0.59          81.0
# 8976  Role-Playing  Konami Digital Entertainment          0.15          83.0
#
#       User_Score Developer Rating
# 3417         9.6      TOSE      E
# 8976         9.6      KCEJ      E

# %%
avg_user_score = global_sales['User_Score'].astype(float).mean().round()
print("Average User Score:",avg_user_score)
# Out:
# Average User Score: 7.0

# %%
avg_score_by_platform = global_sales.groupby(['Platform']).mean().sort_values(by = ['Global_Sales'], ascending= False)
print("Average Scores based on Platform(Console)")
avg_score_by_platform #
# Out:
# Average Scores based on Platform(Console)
# C:\Users\bwelp\AppData\Local\Temp\ipykernel_12496\2910075540.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avg_score_by_platform = global_sales.groupby(['Platform']).mean().sort_values(by = ['Global_Sales'], ascending= False)
#           Global_Sales  Critic_Score  User_Score
# Platform
# PS            1.377000     73.853333    7.860000
# Wii           1.375741     64.175365    6.903758
# PS3           1.019896     70.953186    6.782705
# PS4           1.016862     72.669456    6.739331
# X360          0.994522     69.041958    6.780769
# PS2           0.829798     69.492105    7.664386
# DS            0.823987     66.523707    7.047198
# XOne          0.814906     73.729560    6.493082
# 3DS           0.795032     68.064516    6.940645
# ...

# %%
avg_score_by_dev = global_sales.groupby(['Developer']).mean().sort_values(by = ['Global_Sales'], ascending= False).head(20)
print("Average Scores based on Developer")#Top 20 Developers with the highest global sales with critic score and user scores.
avg_score_by_dev
# Out:
# Average Scores based on Developer
# C:\Users\bwelp\AppData\Local\Temp\ipykernel_12496\488593611.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avg_score_by_dev = global_sales.groupby(['Developer']).mean().sort_values(by = ['Global_Sales'], ascending= False).head(20)
#                                                     Global_Sales  \
# Developer
# Good Science Studio                                    21.810000
# Retro Studios, Entertainment Analysis & Develop...     12.660000
# Infinity Ward, Sledgehammer Games                       9.923333
# Polyphony Digital                                       9.314286
# Rockstar North                                          8.533571
# DMA Design                                              8.260000
# ...

# %% [markdown]
# The top 20 developers taht sold the most have a higher chance of getting a higher Critic Score and User Score as more data is provided
# ***
# Part 4

# %%
game_count = global_sales['Platform'].value_counts().tolist()
label = list(global_sales['Platform'].value_counts().index.values)
fig, ax = plt.subplots()
fig.set_size_inches(10,10)
ax.pie(game_count,labels = label,autopct='%1.1f%%')
ax.set_title('Games Produced Based on Platform')

plt.show()

# %% [markdown]
# The Graph above represents the games made from the specific platform ie. the Playstation 2 taking a 16.7 percentage chunk from the game pool.

# %%
usr_score = global_sales['User_Score'].tolist()
cscore = global_sales['Critic_Score'].tolist()
u_score = []
for i in range(len(usr_score)):
    u_score.append(usr_score[i] * 10) 

fig, ax = plt.subplots()
fig.set_size_inches(15,15)
plt.scatter(u_score,cscore)

line = mlines.Line2D([0, 1], [0, 1], color='red')
transform = ax.transAxes
line.set_transform(transform)
ax.add_line(line)

plt.xlabel('User Score')
plt.ylabel('Critic Score')
plt.title('Ciritc Score vs User Score Scatterplot')

plt.show()

# %% [markdown]
# Graph above shows the comparison of User Scores and Critic Score. The line represents the User score and critic score are the same value thus the game score is accurate from the critics and from players that played the game.
